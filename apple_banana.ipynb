# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
apple_width=np.random.normal(5,0.5,700) 
apple_length=np.random.normal(5,0.5,700)

# %%
banana_width=np.random.normal(4,0.6,700) 
banana_length=np.random.normal(8,0.6,700)

# %%
plt.scatter(apple_width , apple_length , color="red")
plt.scatter(banana_width , banana_length , color="yellow")
plt.show()
